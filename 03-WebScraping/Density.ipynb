# %%
# !pip install Pandas
# Out:
# Requirement already satisfied: Pandas in c:\users\adria\appdata\local\programs\python\python312\lib\site-packages (2.2.2)
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy>=1.26.0 in c:\users\adria\appdata\local\programs\python\python312\lib\site-packages (from Pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\adria\appdata\local\programs\python\python312\lib\site-packages (from Pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\adria\appdata\local\programs\python\python312\lib\site-packages (from Pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\adria\appdata\local\programs\python\python312\lib\site-packages (from Pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\adria\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->Pandas) (1.16.0)

# %%
from bs4 import BeautifulSoup as BS
import requests
import locale
import pandas as pd

locale.setlocale(locale.LC_ALL, 'en_US.UTF-8')
# Out:
# 'en_US.UTF-8'

# %%
html_text = requests.get('https://www.scrapethissite.com/pages/simple/').text

# %%
html_parsed = BS(html_text, 'html.parser')

# %% [markdown]
# ## Extractiong Data

# %%
# Extractiong Data

country_list = html_parsed.find_all(class_='country-name')
population_list = html_parsed.find_all(class_='country-population')
area_list = html_parsed.find_all(class_='country-area')

# %% [markdown]
# ## Processing Data

# %%
def calc_density(population, area):
    result = 0    
    if population == 0.00:
        result = population
    else:
        result = (population / area)

    return result

# %%
# Processing Data
countries = []
for country, population, area in zip(country_list, population_list, area_list):

    text_country = country.text.strip()
    float_population = float(population.text.strip())
    float_area = float(area.text.strip())
    
    dic = {'Country': text_country, 
           'Population': float_population, 
           'Area': float_area,
           'Density (hab/km²)': calc_density(float_population, float_area)
          }
    countries.append(dic)

# %%
countries
# Out:
# [{'Country': 'Andorra',
#   'Population': 84000.0,
#   'Area': 468.0,
#   'Density (hab/km²)': 179.48717948717947},
#  {'Country': 'United Arab Emirates',
#   'Population': 4975593.0,
#   'Area': 82880.0,
#   'Density (hab/km²)': 60.033699324324324},
#  {'Country': 'Afghanistan',
#   'Population': 29121286.0,
#   'Area': 647500.0,
#   'Density (hab/km²)': 44.974959073359074},
#  {'Country': 'Antigua and Barbuda',
#   'Population': 86754.0,
#   'Area': 443.0,
#   'Density (hab/km²)': 195.83295711060947},
#  {'Country': 'Anguilla',
#   'Population': 13254.0,
#   'Area': 102.0,
#   'Density (hab/km²)': 129.94117647058823},
#  {'Country': 'Albania',
#   'Population': 2986952.0,
#   'Area': 28748.0,
#   'Density (hab/km²)': 103.90121051899263},
#  {'Country': 'Armenia',
#   'Population': 2968000.0,
#   'Area': 29800.0,
#   'Density (hab/km²)': 99.59731543624162},
#  {'Country': 'Angola',
#   'Population': 13068161.0,
#   'Area': 1246700.0,
#   'Density (hab/km²)': 10.482201812785755},
#  {'Country': 'Antarctica',
#   'Population': 0.0,
#   'Area': 14000000.0,
#   'Density (hab/km²)': 0.0},
#  {'Country': 'Argentina',
#   'Population': 41343201.0,
#   'Area': 2766890.0,
#   'Density (hab/km²)': 14.942119491559115},
#  {'Country': 'American Samoa',
#   'Population': 57881.0,
#   'Area': 199.0,
#   'Density (hab/km²)': 290.85929648241205},
#  {'Country': 'Austria',
#   'Population': 8205000.0,
#   'Area': 83858.0,
#   'Density (hab/km²)': 97.84397433757066},
#  {'Country': 'Australia',
#   'Population': 21515754.0,
#   'Area': 7686850.0,
#   'Density (hab/km²)': 2.799033934576582},
#  {'Country': 'Aruba',
#   'Population': 71566.0,
#   'Area': 193.0,
#   'Density (hab/km²)': 370.80829015544043},
#  {'Country': 'Åland',
#   'Population': 26711.0,
#   'Area': 1580.0,
#   'Density (hab/km²)': 16.905696202531647},
#  {'Country': 'Azerbaijan',
#   'Population': 8303512.0,
#   'Area': 86600.0,
#   'Density (hab/km²)': 95.8835103926097},
#  {'Country': 'Bosnia and Herzegovina',
#   'Population': 4590000.0,
#   'Area': 51129.0,
#   'Density (hab/km²)': 89.77292730153142},
#  {'Country': 'Barbados',
#   'Population': 285653.0,
#   'Area': 431.0,
#   'Density (hab/km²)': 662.7679814385151},
#  {'Country': 'Bangladesh',
#   'Population': 156118464.0,
#   'Area': 144000.0,
#   'Density (hab/km²)': 1084.156},
#  {'Country': 'Belgium',
#   'Population': 10403000.0,
#   'Area': 30510.0,
#   'Density (hab/km²)': 340.97017371353655},
#  {'Country': 'Burkina Faso',
#   'Population': 16241811.0,
#   'Area': 274200.0,
#   'Density (hab/km²)': 59.23344638949672},
#  {'Country': 'Bulgaria',
#   'Population': 7148785.0,
#   'Area': 110910.0,
#   'Density (hab/km²)': 64.45572987106664},
#  {'Country': 'Bahrain',
#   'Population': 738004.0,
#   'Area': 665.0,
#   'Density (hab/km²)': 1109.7804511278196},
#  {'Country': 'Burundi',
#   'Population': 9863117.0,
#   'Area': 27830.0,
#   'Density (hab/km²)': 354.4059288537549},
#  {'Country': 'Benin',
#   'Population': 9056010.0,
#   'Area': 112620.0,
#   'Density (hab/km²)': 80.41209376664891},
#  {'Country': 'Saint Barthélemy',
#   'Population': 8450.0,
#   'Area': 21.0,
#   'Density (hab/km²)': 402.3809523809524},
#  {'Country': 'Bermuda',
#   'Population': 65365.0,
#   'Area': 53.0,
#   'Density (hab/km²)': 1233.301886792453},
#  {'Country': 'Brunei',
#   'Population': 395027.0,
#   'Area': 5770.0,
#   'Density (hab/km²)': 68.46221837088389},
#  {'Country': 'Bolivia',
#   'Population': 9947418.0,
#   'Area': 1098580.0,
#   'Density (hab/km²)': 9.05479619144714},
#  {'Country': 'Bonaire',
#   'Population': 18012.0,
#   'Area': 328.0,
#   'Density (hab/km²)': 54.91463414634146},
#  {'Country': 'Brazil',
#   'Population': 201103330.0,
#   'Area': 8511965.0,
#   'Density (hab/km²)': 23.62595828342809},
#  {'Country': 'Bahamas',
#   'Population': 301790.0,
#   'Area': 13940.0,
#   'Density (hab/km²)': 21.649210903873744},
#  {'Country': 'Bhutan',
#   'Population': 699847.0,
#   'Area': 47000.0,
#   'Density (hab/km²)': 14.89036170212766},
#  {'Country': 'Bouvet Island',
#   'Population': 0.0,
#   'Area': 49.0,
#   'Density (hab/km²)': 0.0},
#  {'Country': 'Botswana',
#   'Population': 2029307.0,
#   'Area': 600370.0,
#   'Density (hab/km²)': 3.3800939420690574},
#  {'Country': 'Belarus',
#   'Population': 9685000.0,
#   'Area': 207600.0,
#   'Density (hab/km²)': 46.652215799614645},
#  {'Country': 'Belize',
#   'Population': 314522.0,
#   'Area': 22966.0,
#   'Density (hab/km²)': 13.695114517112254},
#  {'Country': 'Canada',
#   'Population': 33679000.0,
#   'Area': 9984670.0,
#   'Density (hab/km²)': 3.37307091771686},
#  {'Country': 'Cocos [Keeling] Islands',
#   'Population': 628.0,
#   'Area': 14.0,
#   'Density (hab/km²)': 44.857142857142854},
#  {'Country': 'Democratic Republic of the Congo',
#   'Population': 70916439.0,
#   'Area': 2345410.0,
#   'Density (hab/km²)': 30.236265301162696},
#  {'Country': 'Central African Republic',
#   'Population': 4844927.0,
#   'Area': 622984.0,
#   'Density (hab/km²)': 7.776968589883528},
#  {'Country': 'Republic of the Congo',
#   'Population': 3039126.0,
#   'Area': 342000.0,
#   'Density (hab/km²)': 8.886333333333333},
#  {'Country': 'Switzerland',
#   'Population': 7581000.0,
#   'Area': 41290.0,
#   'Density (hab/km²)': 183.60377815451685},
#  {'Country': 'Ivory Coast',
#   'Population': 21058798.0,
#   'Area': 322460.0,
#   'Density (hab/km²)': 65.30669850524096},
#  {'Country': 'Cook Islands',
#   'Population': 21388.0,
#   'Area': 240.0,
#   'Density (hab/km²)': 89.11666666666666},
#  {'Country': 'Chile',
#   'Population': 16746491.0,
#   'Area': 756950.0,
#   'Density (hab/km²)': 22.12364224849726},
#  {'Country': 'Cameroon',
#   'Population': 19294149.0,
#   'Area': 475440.0,
#   'Density (hab/km²)': 40.58166961130742},
#  {'Country': 'China',
#   'Population': 1330044000.0,
#   'Area': 9596960.0,
#   'Density (hab/km²)': 138.5901368766776},
#  {'Country': 'Colombia',
#   'Population': 47790000.0,
#   'Area': 1138910.0,
#   'Density (hab/km²)': 41.96117340263937},
#  {'Country': 'Costa Rica',
#   'Population': 4516220.0,
#   'Area': 51100.0,
#   'Density (hab/km²)': 88.38003913894325},
#  {'Country': 'Cuba',
#   'Population': 11423000.0,
#   'Area': 110860.0,
#   'Density (hab/km²)': 103.03987010644056},
#  {'Country': 'Cape Verde',
#   'Population': 508659.0,
#   'Area': 4033.0,
#   'Density (hab/km²)': 126.12422514257376},
#  {'Country': 'Curacao',
#   'Population': 141766.0,
#   'Area': 444.0,
#   'Density (hab/km²)': 319.2927927927928},
#  {'Country': 'Christmas Island',
#   'Population': 1500.0,
#   'Area': 135.0,
#   'Density (hab/km²)': 11.11111111111111},
#  {'Country': 'Cyprus',
#   'Population': 1102677.0,
#   'Area': 9250.0,
#   'Density (hab/km²)': 119.20832432432432},
#  {'Country': 'Czech Republic',
#   'Population': 10476000.0,
#   'Area': 78866.0,
#   'Density (hab/km²)': 132.83290644891335},
#  {'Country': 'Germany',
#   'Population': 81802257.0,
#   'Area': 357021.0,
#   'Density (hab/km²)': 229.1244968783349},
#  {'Country': 'Djibouti',
#   'Population': 740528.0,
#   'Area': 23000.0,
#   'Density (hab/km²)': 32.19686956521739},
#  {'Country': 'Denmark',
#   'Population': 5484000.0,
#   'Area': 43094.0,
#   'Density (hab/km²)': 127.25669466747111},
#  {'Country': 'Dominica',
#   'Population': 72813.0,
#   'Area': 754.0,
#   'Density (hab/km²)': 96.56896551724138},
#  {'Country': 'Dominican Republic',
#   'Population': 9823821.0,
#   'Area': 48730.0,
#   'Density (hab/km²)': 201.59698337779602},
#  {'Country': 'Algeria',
#   'Population': 34586184.0,
#   'Area': 2381740.0,
#   'Density (hab/km²)': 14.52139360299613},
#  {'Country': 'Ecuador',
#   'Population': 14790608.0,
#   'Area': 283560.0,
#   'Density (hab/km²)': 52.16041754831429},
#  {'Country': 'Estonia',
#   'Population': 1291170.0,
#   'Area': 45226.0,
#   'Density (hab/km²)': 28.54928580904789},
#  {'Country': 'Egypt',
#   'Population': 80471869.0,
#   'Area': 1001450.0,
#   'Density (hab/km²)': 80.35535373708123},
#  {'Country': 'Western Sahara',
#   'Population': 273008.0,
#   'Area': 266000.0,
#   'Density (hab/km²)': 1.0263458646616541},
#  {'Country': 'Eritrea',
#   'Population': 5792984.0,
#   'Area': 121320.0,
#   'Density (hab/km²)': 47.749620837454664},
#  {'Country': 'Spain',
#   'Population': 46505963.0,
#   'Area': 504782.0,
#   'Density (hab/km²)': 92.13078715168132},
#  {'Country': 'Ethiopia',
#   'Population': 88013491.0,
#   'Area': 1127127.0,
#   'Density (hab/km²)': 78.08657853107947},
#  {'Country': 'Finland',
#   'Population': 5244000.0,
#   'Area': 337030.0,
#   'Density (hab/km²)': 15.559445746669436},
#  {'Country': 'Fiji',
#   'Population': 875983.0,
#   'Area': 18270.0,
#   'Density (hab/km²)': 47.94652435686918},
#  {'Country': 'Falkland Islands',
#   'Population': 2638.0,
#   'Area': 12173.0,
#   'Density (hab/km²)': 0.2167091103261316},
#  {'Country': 'Micronesia',
#   'Population': 107708.0,
#   'Area': 702.0,
#   'Density (hab/km²)': 153.43019943019942},
#  {'Country': 'Faroe Islands',
#   'Population': 48228.0,
#   'Area': 1399.0,
#   'Density (hab/km²)': 34.473195139385275},
#  {'Country': 'France',
#   'Population': 64768389.0,
#   'Area': 547030.0,
#   'Density (hab/km²)': 118.40006763797233},
#  {'Country': 'Gabon',
#   'Population': 1545255.0,
#   'Area': 267667.0,
#   'Density (hab/km²)': 5.773050095828025},
#  {'Country': 'United Kingdom',
#   'Population': 62348447.0,
#   'Area': 244820.0,
#   'Density (hab/km²)': 254.67056204558452},
#  {'Country': 'Grenada',
#   'Population': 107818.0,
#   'Area': 344.0,
#   'Density (hab/km²)': 313.4244186046512},
#  {'Country': 'Georgia',
#   'Population': 4630000.0,
#   'Area': 69700.0,
#   'Density (hab/km²)': 66.42754662840746},
#  {'Country': 'French Guiana',
#   'Population': 195506.0,
#   'Area': 91000.0,
#   'Density (hab/km²)': 2.1484175824175824},
#  {'Country': 'Guernsey',
#   'Population': 65228.0,
#   'Area': 78.0,
#   'Density (hab/km²)': 836.2564102564103},
#  {'Country': 'Ghana',
#   'Population': 24339838.0,
#   'Area': 239460.0,
#   'Density (hab/km²)': 101.64469222417105},
#  {'Country': 'Gibraltar',
#   'Population': 27884.0,
#   'Area': 6.5,
#   'Density (hab/km²)': 4289.846153846154},
#  {'Country': 'Greenland',
#   'Population': 56375.0,
#   'Area': 2166086.0,
#   'Density (hab/km²)': 0.026026205792383128},
#  {'Country': 'Gambia',
#   'Population': 1593256.0,
#   'Area': 11300.0,
#   'Density (hab/km²)': 140.99610619469027},
#  {'Country': 'Guinea',
#   'Population': 10324025.0,
#   'Area': 245857.0,
#   'Density (hab/km²)': 41.9919912794836},
#  {'Country': 'Guadeloupe',
#   'Population': 443000.0,
#   'Area': 1780.0,
#   'Density (hab/km²)': 248.87640449438203},
#  {'Country': 'Equatorial Guinea',
#   'Population': 1014999.0,
#   'Area': 28051.0,
#   'Density (hab/km²)': 36.18405760935439},
#  {'Country': 'Greece',
#   'Population': 11000000.0,
#   'Area': 131940.0,
#   'Density (hab/km²)': 83.37122934667273},
#  {'Country': 'South Georgia and the South Sandwich Islands',
#   'Population': 30.0,
#   'Area': 3903.0,
#   'Density (hab/km²)': 0.007686395080707148},
#  {'Country': 'Guatemala',
#   'Population': 13550440.0,
#   'Area': 108890.0,
#   'Density (hab/km²)': 124.44154651483149},
#  {'Country': 'Guam',
#   'Population': 159358.0,
#   'Area': 549.0,
#   'Density (hab/km²)': 290.2695810564663},
#  {'Country': 'Guinea-Bissau',
#   'Population': 1565126.0,
#   'Area': 36120.0,
#   'Density (hab/km²)': 43.331284606866},
#  {'Country': 'Guyana',
#   'Population': 748486.0,
#   'Area': 214970.0,
#   'Density (hab/km²)': 3.481816067358236},
#  {'Country': 'Hong Kong',
#   'Population': 6898686.0,
#   'Area': 1092.0,
#   'Density (hab/km²)': 6317.478021978022},
#  {'Country': 'Heard Island and McDonald Islands',
#   'Population': 0.0,
#   'Area': 412.0,
#   'Density (hab/km²)': 0.0},
#  {'Country': 'Honduras',
#   'Population': 7989415.0,
#   'Area': 112090.0,
#   'Density (hab/km²)': 71.2767865108395},
#  {'Country': 'Croatia',
#   'Population': 4491000.0,
#   'Area': 56542.0,
#   'Density (hab/km²)': 79.42768207704007},
#  {'Country': 'Haiti',
#   'Population': 9648924.0,
#   'Area': 27750.0,
#   'Density (hab/km²)': 347.70897297297296},
#  {'Country': 'Hungary',
#   'Population': 9982000.0,
#   'Area': 93030.0,
#   'Density (hab/km²)': 107.2987208427389},
#  {'Country': 'Indonesia',
#   'Population': 242968342.0,
#   'Area': 1919440.0,
#   'Density (hab/km²)': 126.582931480015},
#  {'Country': 'Ireland',
#   'Population': 4622917.0,
#   'Area': 70280.0,
#   'Density (hab/km²)': 65.77855719977234},
#  {'Country': 'Israel',
#   'Population': 7353985.0,
#   'Area': 20770.0,
#   'Density (hab/km²)': 354.067645642754},
#  {'Country': 'Isle of Man',
#   'Population': 75049.0,
#   'Area': 572.0,
#   'Density (hab/km²)': 131.20454545454547},
#  {'Country': 'India',
#   'Population': 1173108018.0,
#   'Area': 3287590.0,
#   'Density (hab/km²)': 356.82917212912804},
#  {'Country': 'British Indian Ocean Territory',
#   'Population': 4000.0,
#   'Area': 60.0,
#   'Density (hab/km²)': 66.66666666666667},
#  {'Country': 'Iraq',
#   'Population': 29671605.0,
#   'Area': 437072.0,
#   'Density (hab/km²)': 67.88722453051213},
#  {'Country': 'Iran',
#   'Population': 76923300.0,
#   'Area': 1648000.0,
#   'Density (hab/km²)': 46.67675970873786},
#  {'Country': 'Iceland',
#   'Population': 308910.0,
#   'Area': 103000.0,
#   'Density (hab/km²)': 2.999126213592233},
#  {'Country': 'Italy',
#   'Population': 60340328.0,
#   'Area': 301230.0,
#   'Density (hab/km²)': 200.31314278126348},
#  {'Country': 'Jersey',
#   'Population': 90812.0,
#   'Area': 116.0,
#   'Density (hab/km²)': 782.8620689655172},
#  {'Country': 'Jamaica',
#   'Population': 2847232.0,
#   'Area': 10991.0,
#   'Density (hab/km²)': 259.05122372850514},
#  {'Country': 'Jordan',
#   'Population': 6407085.0,
#   'Area': 92300.0,
#   'Density (hab/km²)': 69.415872156013},
#  {'Country': 'Japan',
#   'Population': 127288000.0,
#   'Area': 377835.0,
#   'Density (hab/km²)': 336.88779493694335},
#  {'Country': 'Kenya',
#   'Population': 40046566.0,
#   'Area': 582650.0,
#   'Density (hab/km²)': 68.73177035956407},
#  {'Country': 'Kyrgyzstan',
#   'Population': 5776500.0,
#   'Area': 198500.0,
#   'Density (hab/km²)': 29.1007556675063},
#  {'Country': 'Cambodia',
#   'Population': 14453680.0,
#   'Area': 181040.0,
#   'Density (hab/km²)': 79.8369421122404},
#  {'Country': 'Kiribati',
#   'Population': 92533.0,
#   'Area': 811.0,
#   'Density (hab/km²)': 114.09741060419236},
#  {'Country': 'Comoros',
#   'Population': 773407.0,
#   'Area': 2170.0,
#   'Density (hab/km²)': 356.40875576036865},
#  {'Country': 'Saint Kitts and Nevis',
#   'Population': 51134.0,
#   'Area': 261.0,
#   'Density (hab/km²)': 195.91570881226053},
#  {'Country': 'North Korea',
#   'Population': 22912177.0,
#   'Area': 120540.0,
#   'Density (hab/km²)': 190.07945080471214},
#  {'Country': 'South Korea',
#   'Population': 48422644.0,
#   'Area': 98480.0,
#   'Density (hab/km²)': 491.7002843216897},
#  {'Country': 'Kuwait',
#   'Population': 2789132.0,
#   'Area': 17820.0,
#   'Density (hab/km²)': 156.5169472502806},
#  {'Country': 'Cayman Islands',
#   'Population': 44270.0,
#   'Area': 262.0,
#   'Density (hab/km²)': 168.96946564885496},
#  {'Country': 'Kazakhstan',
#   'Population': 15340000.0,
#   'Area': 2717300.0,
#   'Density (hab/km²)': 5.645309682405329},
#  {'Country': 'Laos',
#   'Population': 6368162.0,
#   'Area': 236800.0,
#   'Density (hab/km²)': 26.892576013513512},
#  {'Country': 'Lebanon',
#   'Population': 4125247.0,
#   'Area': 10400.0,
#   'Density (hab/km²)': 396.65836538461537},
#  {'Country': 'Saint Lucia',
#   'Population': 160922.0,
#   'Area': 616.0,
#   'Density (hab/km²)': 261.237012987013},
#  {'Country': 'Liechtenstein',
#   'Population': 35000.0,
#   'Area': 160.0,
#   'Density (hab/km²)': 218.75},
#  {'Country': 'Sri Lanka',
#   'Population': 21513990.0,
#   'Area': 65610.0,
#   'Density (hab/km²)': 327.907178783722},
#  {'Country': 'Liberia',
#   'Population': 3685076.0,
#   'Area': 111370.0,
#   'Density (hab/km²)': 33.08858759091317},
#  {'Country': 'Lesotho',
#   'Population': 1919552.0,
#   'Area': 30355.0,
#   'Density (hab/km²)': 63.236764948113986},
#  {'Country': 'Lithuania',
#   'Population': 2944459.0,
#   'Area': 65200.0,
#   'Density (hab/km²)': 45.16041411042945},
#  {'Country': 'Luxembourg',
#   'Population': 497538.0,
#   'Area': 2586.0,
#   'Density (hab/km²)': 192.39675174013922},
#  {'Country': 'Latvia',
#   'Population': 2217969.0,
#   'Area': 64589.0,
#   'Density (hab/km²)': 34.339732771834214},
#  {'Country': 'Libya',
#   'Population': 6461454.0,
#   'Area': 1759540.0,
#   'Density (hab/km²)': 3.6722404719415302},
#  {'Country': 'Morocco',
#   'Population': 31627428.0,
#   'Area': 446550.0,
#   'Density (hab/km²)': 70.82617400067181},
#  {'Country': 'Monaco',
#   'Population': 32965.0,
#   'Area': 1.95,
#   'Density (hab/km²)': 16905.128205128207},
#  {'Country': 'Moldova',
#   'Population': 4324000.0,
#   'Area': 33843.0,
#   'Density (hab/km²)': 127.76645096474898},
#  {'Country': 'Montenegro',
#   'Population': 666730.0,
#   'Area': 14026.0,
#   'Density (hab/km²)': 47.53529160131185},
#  {'Country': 'Saint Martin',
#   'Population': 35925.0,
#   'Area': 53.0,
#   'Density (hab/km²)': 677.8301886792453},
#  {'Country': 'Madagascar',
#   'Population': 21281844.0,
#   'Area': 587040.0,
#   'Density (hab/km²)': 36.25280049059689},
#  {'Country': 'Marshall Islands',
#   'Population': 65859.0,
#   'Area': 181.3,
#   'Density (hab/km²)': 363.2597904026475},
#  {'Country': 'Macedonia',
#   'Population': 2062294.0,
#   'Area': 25333.0,
#   'Density (hab/km²)': 81.40741325543758},
#  {'Country': 'Mali',
#   'Population': 13796354.0,
#   'Area': 1240000.0,
#   'Density (hab/km²)': 11.12609193548387},
#  {'Country': 'Myanmar [Burma]',
#   'Population': 53414374.0,
#   'Area': 678500.0,
#   'Density (hab/km²)': 78.72420633750922},
#  {'Country': 'Mongolia',
#   'Population': 3086918.0,
#   'Area': 1565000.0,
#   'Density (hab/km²)': 1.9724715654952076},
#  {'Country': 'Macao',
#   'Population': 449198.0,
#   'Area': 254.0,
#   'Density (hab/km²)': 1768.4960629921259},
#  {'Country': 'Northern Mariana Islands',
#   'Population': 53883.0,
#   'Area': 477.0,
#   'Density (hab/km²)': 112.9622641509434},
#  {'Country': 'Martinique',
#   'Population': 432900.0,
#   'Area': 1100.0,
#   'Density (hab/km²)': 393.54545454545456},
#  {'Country': 'Mauritania',
#   'Population': 3205060.0,
#   'Area': 1030700.0,
#   'Density (hab/km²)': 3.10959542058795},
#  {'Country': 'Montserrat',
#   'Population': 9341.0,
#   'Area': 102.0,
#   'Density (hab/km²)': 91.57843137254902},
#  {'Country': 'Malta',
#   'Population': 403000.0,
#   'Area': 316.0,
#   'Density (hab/km²)': 1275.3164556962026},
#  {'Country': 'Mauritius',
#   'Population': 1294104.0,
#   'Area': 2040.0,
#   'Density (hab/km²)': 634.364705882353},
#  {'Country': 'Maldives',
#   'Population': 395650.0,
#   'Area': 300.0,
#   'Density (hab/km²)': 1318.8333333333333},
#  {'Country': 'Malawi',
#   'Population': 15447500.0,
#   'Area': 118480.0,
#   'Density (hab/km²)': 130.38065496286293},
#  {'Country': 'Mexico',
#   'Population': 112468855.0,
#   'Area': 1972550.0,
#   'Density (hab/km²)': 57.016985627740745},
#  {'Country': 'Malaysia',
#   'Population': 28274729.0,
#   'Area': 329750.0,
#   'Density (hab/km²)': 85.7459560272934},
#  {'Country': 'Mozambique',
#   'Population': 22061451.0,
#   'Area': 801590.0,
#   'Density (hab/km²)': 27.522113549320725},
#  {'Country': 'Namibia',
#   'Population': 2128471.0,
#   'Area': 825418.0,
#   'Density (hab/km²)': 2.578658328265194},
#  {'Country': 'New Caledonia',
#   'Population': 216494.0,
#   'Area': 19060.0,
#   'Density (hab/km²)': 11.358551941238195},
#  {'Country': 'Niger',
#   'Population': 15878271.0,
#   'Area': 1267000.0,
#   'Density (hab/km²)': 12.532179163378059},
#  {'Country': 'Norfolk Island',
#   'Population': 1828.0,
#   'Area': 34.6,
#   'Density (hab/km²)': 52.83236994219653},
#  {'Country': 'Nigeria',
#   'Population': 154000000.0,
#   'Area': 923768.0,
#   'Density (hab/km²)': 166.70852421820197},
#  {'Country': 'Nicaragua',
#   'Population': 5995928.0,
#   'Area': 129494.0,
#   'Density (hab/km²)': 46.30274761765024},
#  {'Country': 'Netherlands',
#   'Population': 16645000.0,
#   'Area': 41526.0,
#   'Density (hab/km²)': 400.83321292684104},
#  {'Country': 'Norway',
#   'Population': 5009150.0,
#   'Area': 324220.0,
#   'Density (hab/km²)': 15.449848868052557},
#  {'Country': 'Nepal',
#   'Population': 28951852.0,
#   'Area': 140800.0,
#   'Density (hab/km²)': 205.62394886363637},
#  {'Country': 'Nauru',
#   'Population': 10065.0,
#   'Area': 21.0,
#   'Density (hab/km²)': 479.2857142857143},
#  {'Country': 'Niue',
#   'Population': 2166.0,
#   'Area': 260.0,
#   'Density (hab/km²)': 8.330769230769231},
#  {'Country': 'New Zealand',
#   'Population': 4252277.0,
#   'Area': 268680.0,
#   'Density (hab/km²)': 15.826548310257555},
#  {'Country': 'Oman',
#   'Population': 2967717.0,
#   'Area': 212460.0,
#   'Density (hab/km²)': 13.968356396498164},
#  {'Country': 'Panama',
#   'Population': 3410676.0,
#   'Area': 78200.0,
#   'Density (hab/km²)': 43.614782608695656},
#  {'Country': 'Peru',
#   'Population': 29907003.0,
#   'Area': 1285220.0,
#   'Density (hab/km²)': 23.2699483356935},
#  {'Country': 'French Polynesia',
#   'Population': 270485.0,
#   'Area': 4167.0,
#   'Density (hab/km²)': 64.91120710343172},
#  {'Country': 'Papua New Guinea',
#   'Population': 6064515.0,
#   'Area': 462840.0,
#   'Density (hab/km²)': 13.10283251231527},
#  {'Country': 'Philippines',
#   'Population': 99900177.0,
#   'Area': 300000.0,
#   'Density (hab/km²)': 333.00059},
#  {'Country': 'Pakistan',
#   'Population': 184404791.0,
#   'Area': 803940.0,
#   'Density (hab/km²)': 229.3763104211757},
#  {'Country': 'Poland',
#   'Population': 38500000.0,
#   'Area': 312685.0,
#   'Density (hab/km²)': 123.12710875161905},
#  {'Country': 'Saint Pierre and Miquelon',
#   'Population': 7012.0,
#   'Area': 242.0,
#   'Density (hab/km²)': 28.975206611570247},
#  {'Country': 'Pitcairn Islands',
#   'Population': 46.0,
#   'Area': 47.0,
#   'Density (hab/km²)': 0.9787234042553191},
#  {'Country': 'Puerto Rico',
#   'Population': 3916632.0,
#   'Area': 9104.0,
#   'Density (hab/km²)': 430.2100175746924},
#  {'Country': 'Palestine',
#   'Population': 3800000.0,
#   'Area': 5970.0,
#   'Density (hab/km²)': 636.5159128978224},
#  {'Country': 'Portugal',
#   'Population': 10676000.0,
#   'Area': 92391.0,
#   'Density (hab/km²)': 115.55238064313623},
#  {'Country': 'Palau',
#   'Population': 19907.0,
#   'Area': 458.0,
#   'Density (hab/km²)': 43.46506550218341},
#  {'Country': 'Paraguay',
#   'Population': 6375830.0,
#   'Area': 406750.0,
#   'Density (hab/km²)': 15.675058389674247},
#  {'Country': 'Qatar',
#   'Population': 840926.0,
#   'Area': 11437.0,
#   'Density (hab/km²)': 73.52679898574802},
#  {'Country': 'Réunion',
#   'Population': 776948.0,
#   'Area': 2517.0,
#   'Density (hab/km²)': 308.6801748112833},
#  {'Country': 'Romania',
#   'Population': 21959278.0,
#   'Area': 237500.0,
#   'Density (hab/km²)': 92.46011789473684},
#  {'Country': 'Serbia',
#   'Population': 7344847.0,
#   'Area': 88361.0,
#   'Density (hab/km²)': 83.12317651452564},
#  {'Country': 'Russia',
#   'Population': 140702000.0,
#   'Area': 17100000.0,
#   'Density (hab/km²)': 8.228187134502924},
#  {'Country': 'Rwanda',
#   'Population': 11055976.0,
#   'Area': 26338.0,
#   'Density (hab/km²)': 419.7727997570051},
#  {'Country': 'Saudi Arabia',
#   'Population': 25731776.0,
#   'Area': 1960582.0,
#   'Density (hab/km²)': 13.124559952095858},
#  {'Country': 'Solomon Islands',
#   'Population': 559198.0,
#   'Area': 28450.0,
#   'Density (hab/km²)': 19.655465729349736},
#  {'Country': 'Seychelles',
#   'Population': 88340.0,
#   'Area': 455.0,
#   'Density (hab/km²)': 194.15384615384616},
#  {'Country': 'Sudan',
#   'Population': 35000000.0,
#   'Area': 1861484.0,
#   'Density (hab/km²)': 18.80220297354154},
#  {'Country': 'Sweden',
#   'Population': 9828655.0,
#   'Area': 449964.0,
#   'Density (hab/km²)': 21.8432030117965},
#  {'Country': 'Singapore',
#   'Population': 4701069.0,
#   'Area': 692.7,
#   'Density (hab/km²)': 6786.5872672152445},
#  {'Country': 'Saint Helena',
#   'Population': 7460.0,
#   'Area': 410.0,
#   'Density (hab/km²)': 18.195121951219512},
#  {'Country': 'Slovenia',
#   'Population': 2007000.0,
#   'Area': 20273.0,
#   'Density (hab/km²)': 98.99866817935185},
#  {'Country': 'Svalbard and Jan Mayen',
#   'Population': 2550.0,
#   'Area': 62049.0,
#   'Density (hab/km²)': 0.0410965527244597},
#  {'Country': 'Slovakia',
#   'Population': 5455000.0,
#   'Area': 48845.0,
#   'Density (hab/km²)': 111.67980345992424},
#  {'Country': 'Sierra Leone',
#   'Population': 5245695.0,
#   'Area': 71740.0,
#   'Density (hab/km²)': 73.12092277669362},
#  {'Country': 'San Marino',
#   'Population': 31477.0,
#   'Area': 61.2,
#   'Density (hab/km²)': 514.3300653594771},
#  {'Country': 'Senegal',
#   'Population': 12323252.0,
#   'Area': 196190.0,
#   'Density (hab/km²)': 62.81284469137061},
#  {'Country': 'Somalia',
#   'Population': 10112453.0,
#   'Area': 637657.0,
#   'Density (hab/km²)': 15.858765762784694},
#  {'Country': 'Suriname',
#   'Population': 492829.0,
#   'Area': 163270.0,
#   'Density (hab/km²)': 3.0184908433882525},
#  {'Country': 'South Sudan',
#   'Population': 8260490.0,
#   'Area': 644329.0,
#   'Density (hab/km²)': 12.82029832585527},
#  {'Country': 'São Tomé and Príncipe',
#   'Population': 175808.0,
#   'Area': 1001.0,
#   'Density (hab/km²)': 175.63236763236762},
#  {'Country': 'El Salvador',
#   'Population': 6052064.0,
#   'Area': 21040.0,
#   'Density (hab/km²)': 287.64562737642586},
#  {'Country': 'Sint Maarten',
#   'Population': 37429.0,
#   'Area': 21.0,
#   'Density (hab/km²)': 1782.3333333333333},
#  {'Country': 'Syria',
#   'Population': 22198110.0,
#   'Area': 185180.0,
#   'Density (hab/km²)': 119.87315044821256},
#  {'Country': 'Swaziland',
#   'Population': 1354051.0,
#   'Area': 17363.0,
#   'Density (hab/km²)': 77.98485284801014},
#  {'Country': 'Turks and Caicos Islands',
#   'Population': 20556.0,
#   'Area': 430.0,
#   'Density (hab/km²)': 47.8046511627907},
#  {'Country': 'Chad',
#   'Population': 10543464.0,
#   'Area': 1284000.0,
#   'Density (hab/km²)': 8.211420560747664},
#  {'Country': 'French Southern Territories',
#   'Population': 140.0,
#   'Area': 7829.0,
#   'Density (hab/km²)': 0.017882232724485886},
#  {'Country': 'Togo',
#   'Population': 6587239.0,
#   'Area': 56785.0,
#   'Density (hab/km²)': 116.00315224090869},
#  {'Country': 'Thailand',
#   'Population': 67089500.0,
#   'Area': 514000.0,
#   'Density (hab/km²)': 130.52431906614785},
#  {'Country': 'Tajikistan',
#   'Population': 7487489.0,
#   'Area': 143100.0,
#   'Density (hab/km²)': 52.32347309573725},
#  {'Country': 'Tokelau',
#   'Population': 1466.0,
#   'Area': 10.0,
#   'Density (hab/km²)': 146.6},
#  {'Country': 'East Timor',
#   'Population': 1154625.0,
#   'Area': 15007.0,
#   'Density (hab/km²)': 76.93909508895848},
#  {'Country': 'Turkmenistan',
#   'Population': 4940916.0,
#   'Area': 488100.0,
#   'Density (hab/km²)': 10.122753534111862},
#  {'Country': 'Tunisia',
#   'Population': 10589025.0,
#   'Area': 163610.0,
#   'Density (hab/km²)': 64.72113562740664},
#  {'Country': 'Tonga',
#   'Population': 122580.0,
#   'Area': 748.0,
#   'Density (hab/km²)': 163.87700534759358},
#  {'Country': 'Turkey',
#   'Population': 77804122.0,
#   'Area': 780580.0,
#   'Density (hab/km²)': 99.67475723180199},
#  {'Country': 'Trinidad and Tobago',
#   'Population': 1228691.0,
#   'Area': 5128.0,
#   'Density (hab/km²)': 239.60432917316692},
#  {'Country': 'Tuvalu',
#   'Population': 10472.0,
#   'Area': 26.0,
#   'Density (hab/km²)': 402.7692307692308},
#  {'Country': 'Taiwan',
#   'Population': 22894384.0,
#   'Area': 35980.0,
#   'Density (hab/km²)': 636.308615897721},
#  {'Country': 'Tanzania',
#   'Population': 41892895.0,
#   'Area': 945087.0,
#   'Density (hab/km²)': 44.32702491939895},
#  {'Country': 'Ukraine',
#   'Population': 45415596.0,
#   'Area': 603700.0,
#   'Density (hab/km²)': 75.22874937883054},
#  {'Country': 'Uganda',
#   'Population': 33398682.0,
#   'Area': 236040.0,
#   'Density (hab/km²)': 141.49585663446874},
#  {'Country': 'U.S. Minor Outlying Islands',
#   'Population': 0.0,
#   'Area': 0.0,
#   'Density (hab/km²)': 0.0},
#  {'Country': 'United States',
#   'Population': 310232863.0,
#   'Area': 9629091.0,
#   'Density (hab/km²)': 32.218291736987425},
#  {'Country': 'Uruguay',
#   'Population': 3477000.0,
#   'Area': 176220.0,
#   'Density (hab/km²)': 19.731018045624786},
#  {'Country': 'Uzbekistan',
#   'Population': 27865738.0,
#   'Area': 447400.0,
#   'Density (hab/km²)': 62.283723737147966},
#  {'Country': 'Vatican City',
#   'Population': 921.0,
#   'Area': 0.44,
#   'Density (hab/km²)': 2093.181818181818},
#  {'Country': 'Saint Vincent and the Grenadines',
#   'Population': 104217.0,
#   'Area': 389.0,
#   'Density (hab/km²)': 267.91002570694087},
#  {'Country': 'Venezuela',
#   'Population': 27223228.0,
#   'Area': 912050.0,
#   'Density (hab/km²)': 29.84839427662957},
#  {'Country': 'British Virgin Islands',
#   'Population': 21730.0,
#   'Area': 153.0,
#   'Density (hab/km²)': 142.0261437908497},
#  {'Country': 'U.S. Virgin Islands',
#   'Population': 108708.0,
#   'Area': 352.0,
#   'Density (hab/km²)': 308.82954545454544},
#  {'Country': 'Vietnam',
#   'Population': 89571130.0,
#   'Area': 329560.0,
#   'Density (hab/km²)': 271.7900534045394},
#  {'Country': 'Vanuatu',
#   'Population': 221552.0,
#   'Area': 12200.0,
#   'Density (hab/km²)': 18.16},
#  {'Country': 'Wallis and Futuna',
#   'Population': 16025.0,
#   'Area': 274.0,
#   'Density (hab/km²)': 58.48540145985402},
#  {'Country': 'Samoa',
#   'Population': 192001.0,
#   'Area': 2944.0,
#   'Density (hab/km²)': 65.21773097826087},
#  {'Country': 'Kosovo',
#   'Population': 1800000.0,
#   'Area': 10908.0,
#   'Density (hab/km²)': 165.01650165016503},
#  {'Country': 'Yemen',
#   'Population': 23495361.0,
#   'Area': 527970.0,
#   'Density (hab/km²)': 44.50131825671913},
#  {'Country': 'Mayotte',
#   'Population': 159042.0,
#   'Area': 374.0,
#   'Density (hab/km²)': 425.24598930481284},
#  {'Country': 'South Africa',
#   'Population': 49000000.0,
#   'Area': 1219912.0,
#   'Density (hab/km²)': 40.16683170589354},
#  {'Country': 'Zambia',
#   'Population': 13460305.0,
#   'Area': 752614.0,
#   'Density (hab/km²)': 17.88473905614299},
#  {'Country': 'Zimbabwe',
#   'Population': 11651858.0,
#   'Area': 390580.0,
#   'Density (hab/km²)': 29.832193148650724}]

# %% [markdown]
# # Without Pandas

# %% [markdown]
# ## Top 10 countries with the highest density

# %%
heighest_10_dense_countries = sorted(countries, key=lambda x: x['Density (hab/km²)'], reverse=True)[:10]

print('-----------------------------------------')
print('Top 10 countries with the highest density')
print('-----------------------------------------\n')
for index, country in enumerate(heighest_10_dense_countries):
     density = country['Density (hab/km²)']
     print(f"{index+1}° - {country['Country']}: {locale.format_string('%0.2f', density, grouping=True)} hab/km²")
# Out:
# -----------------------------------------
# Top 10 countries with the highest density
# -----------------------------------------
#
# 1° - Monaco: 16,905.13 hab/km²
# 2° - Singapore: 6,786.59 hab/km²
# 3° - Hong Kong: 6,317.48 hab/km²
# 4° - Gibraltar: 4,289.85 hab/km²
# 5° - Vatican City: 2,093.18 hab/km²
# 6° - Sint Maarten: 1,782.33 hab/km²
# 7° - Macao: 1,768.50 hab/km²
# 8° - Maldives: 1,318.83 hab/km²
# 9° - Malta: 1,275.32 hab/km²
# 10° - Bermuda: 1,233.30 hab/km²

# %% [markdown]
# ## Top 10 countries with the lowest density

# %%
lowest_10_dense_countries = sorted(
    [country for country in countries if float(country['Density (hab/km²)']) > 0],
    key=lambda x: x['Density (hab/km²)']
)[:10]

print('-----------------------------------------')
print('Top 10 countries with the lowest density')
print('-----------------------------------------')
for index, country in enumerate(lowest_10_dense_countries):
    density = country['Density (hab/km²)']
    print(f"{index+1}° - {country['Country']}: {locale.format_string('%0.2f', density, grouping=True)} hab/km²")
# Out:
# -----------------------------------------
# Top 10 countries with the lowest density
# -----------------------------------------
# 1° - South Georgia and the South Sandwich Islands: 0.01 hab/km²
# 2° - French Southern Territories: 0.02 hab/km²
# 3° - Greenland: 0.03 hab/km²
# 4° - Svalbard and Jan Mayen: 0.04 hab/km²
# 5° - Falkland Islands: 0.22 hab/km²
# 6° - Pitcairn Islands: 0.98 hab/km²
# 7° - Western Sahara: 1.03 hab/km²
# 8° - Mongolia: 1.97 hab/km²
# 9° - French Guiana: 2.15 hab/km²
# 10° - Namibia: 2.58 hab/km²

# %% [markdown]
# # Pandas

# %%
# Create data frame
df = pd.DataFrame(countries)

# %% [markdown]
# ## Converting a data frame into a table

# %%
df = df[['Country', 'Density (hab/km²)']]

# %% [markdown]
# ## Top 10 countries with the highest density

# %%
def format_number(number):
    return '{:,.2f}'.format(number)

# %%
top_10_highest_density = df.nlargest(10, 'Density (hab/km²)')
top_10_highest_density['Density (hab/km²)'] = top_10_highest_density['Density (hab/km²)'].apply(format_number)

# %%
top_10_highest_density.head(10).style.set_table_styles([ 
    dict( selector='th', props=[('text-align', 'left')]),                                                
    dict( selector='td', props=[('text-align', 'left')])
])
# Out:
# <style type="text/css">
# #T_ffa04 th {
#   text-align: left;
# }
# #T_ffa04 td {
#   text-align: left;
# }
# </style>
# <table id="T_ffa04">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ffa04_level0_col0" class="col_heading level0 col0" >Country</th>
#       <th id="T_ffa04_level0_col1" class="col_heading level0 col1" >Density (hab/km²)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ffa04_level0_row0" class="row_heading level0 row0" >137</th>
#       <td id="T_ffa04_row0_col0" class="data row0 col0" >Monaco</td>
#       <td id="T_ffa04_row0_col1" class="data row0 col1" >16,905.13</td>
#     </tr>
#     <tr>
#       <th id="T_ffa04_level0_row1" class="row_heading level0 row1" >197</th>
#       <td id="T_ffa04_row1_col0" class="data row1 col0" >Singapore</td>
#       <td id="T_ffa04_row1_col1" class="data row1 col1" >6,786.59</td>
#     </tr>
#     <tr>
#       <th id="T_ffa04_level0_row2" class="row_heading level0 row2" >94</th>
#       <td id="T_ffa04_row2_col0" class="data row2 col0" >Hong Kong</td>
#       <td id="T_ffa04_row2_col1" class="data row2 col1" >6,317.48</td>
#     </tr>
#     <tr>
#       <th id="T_ffa04_level0_row3" class="row_heading level0 row3" >82</th>
#       <td id="T_ffa04_row3_col0" class="data row3 col0" >Gibraltar</td>
#       <td id="T_ffa04_row3_col1" class="data row3 col1" >4,289.85</td>
#     </tr>
#     <tr>
#       <th id="T_ffa04_level0_row4" class="row_heading level0 row4" >235</th>
#       <td id="T_ffa04_row4_col0" class="data row4 col0" >Vatican City</td>
#       <td id="T_ffa04_row4_col1" class="data row4 col1" >2,093.18</td>
#     </tr>
#     <tr>
#       <th id="T_ffa04_level0_row5" class="row_heading level0 row5" >210</th>
#       <td id="T_ffa04_row5_col0" class="data row5 col0" >Sint Maarten</td>
#       <td id="T_ffa04_row5_col1" class="data row5 col1" >1,782.33</td>
#     </tr>
#     <tr>
#       <th id="T_ffa04_level0_row6" class="row_heading level0 row6" >147</th>
#       <td id="T_ffa04_row6_col0" class="data row6 col0" >Macao</td>
#       <td id="T_ffa04_row6_col1" class="data row6 col1" >1,768.50</td>
#     </tr>
#     <tr>
#       <th id="T_ffa04_level0_row7" class="row_heading level0 row7" >154</th>
#       <td id="T_ffa04_row7_col0" class="data row7 col0" >Maldives</td>
#       <td id="T_ffa04_row7_col1" class="data row7 col1" >1,318.83</td>
#     </tr>
#     <tr>
#       <th id="T_ffa04_level0_row8" class="row_heading level0 row8" >152</th>
#       <td id="T_ffa04_row8_col0" class="data row8 col0" >Malta</td>
#       <td id="T_ffa04_row8_col1" class="data row8 col1" >1,275.32</td>
#     </tr>
#     <tr>
#       <th id="T_ffa04_level0_row9" class="row_heading level0 row9" >26</th>
#       <td id="T_ffa04_row9_col0" class="data row9 col0" >Bermuda</td>
#       <td id="T_ffa04_row9_col1" class="data row9 col1" >1,233.30</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Top 10 countries with the lowest density

# %%
filtered_df = df[(df['Density (hab/km²)'] > 0.00)]

# %%
top_10_lowest_density = filtered_df.nsmallest(10,'Density (hab/km²)')
top_10_lowest_density['Density (hab/km²)'] = top_10_lowest_density['Density (hab/km²)'].apply(format_number)

# %%
top_10_lowest_density.head(10).style.set_table_styles([ 
    dict( selector='th', props=[('text-align', 'left')]),                                                
    dict( selector='td', props=[('text-align', 'left')])
])
# Out:
# <style type="text/css">
# #T_2f3db th {
#   text-align: left;
# }
# #T_2f3db td {
#   text-align: left;
# }
# </style>
# <table id="T_2f3db">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2f3db_level0_col0" class="col_heading level0 col0" >Country</th>
#       <th id="T_2f3db_level0_col1" class="col_heading level0 col1" >Density (hab/km²)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f3db_level0_row0" class="row_heading level0 row0" >89</th>
#       <td id="T_2f3db_row0_col0" class="data row0 col0" >South Georgia and the South Sandwich Islands</td>
#       <td id="T_2f3db_row0_col1" class="data row0 col1" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_2f3db_level0_row1" class="row_heading level0 row1" >215</th>
#       <td id="T_2f3db_row1_col0" class="data row1 col0" >French Southern Territories</td>
#       <td id="T_2f3db_row1_col1" class="data row1 col1" >0.02</td>
#     </tr>
#     <tr>
#       <th id="T_2f3db_level0_row2" class="row_heading level0 row2" >83</th>
#       <td id="T_2f3db_row2_col0" class="data row2 col0" >Greenland</td>
#       <td id="T_2f3db_row2_col1" class="data row2 col1" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_2f3db_level0_row3" class="row_heading level0 row3" >200</th>
#       <td id="T_2f3db_row3_col0" class="data row3 col0" >Svalbard and Jan Mayen</td>
#       <td id="T_2f3db_row3_col1" class="data row3 col1" >0.04</td>
#     </tr>
#     <tr>
#       <th id="T_2f3db_level0_row4" class="row_heading level0 row4" >71</th>
#       <td id="T_2f3db_row4_col0" class="data row4 col0" >Falkland Islands</td>
#       <td id="T_2f3db_row4_col1" class="data row4 col1" >0.22</td>
#     </tr>
#     <tr>
#       <th id="T_2f3db_level0_row5" class="row_heading level0 row5" >180</th>
#       <td id="T_2f3db_row5_col0" class="data row5 col0" >Pitcairn Islands</td>
#       <td id="T_2f3db_row5_col1" class="data row5 col1" >0.98</td>
#     </tr>
#     <tr>
#       <th id="T_2f3db_level0_row6" class="row_heading level0 row6" >65</th>
#       <td id="T_2f3db_row6_col0" class="data row6 col0" >Western Sahara</td>
#       <td id="T_2f3db_row6_col1" class="data row6 col1" >1.03</td>
#     </tr>
#     <tr>
#       <th id="T_2f3db_level0_row7" class="row_heading level0 row7" >146</th>
#       <td id="T_2f3db_row7_col0" class="data row7 col0" >Mongolia</td>
#       <td id="T_2f3db_row7_col1" class="data row7 col1" >1.97</td>
#     </tr>
#     <tr>
#       <th id="T_2f3db_level0_row8" class="row_heading level0 row8" >79</th>
#       <td id="T_2f3db_row8_col0" class="data row8 col0" >French Guiana</td>
#       <td id="T_2f3db_row8_col1" class="data row8 col1" >2.15</td>
#     </tr>
#     <tr>
#       <th id="T_2f3db_level0_row9" class="row_heading level0 row9" >159</th>
#       <td id="T_2f3db_row9_col0" class="data row9 col0" >Namibia</td>
#       <td id="T_2f3db_row9_col1" class="data row9 col1" >2.58</td>
#     </tr>
#   </tbody>
# </table>
